# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
from scipy.interpolate import spline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_polar = pd.read_csv('result_polar.txt', sep = ';', names = ['R','Lengh', 'SNR', 'error', 'method'])
df_ldpc = pd.read_csv('result_ldpc.txt', sep = ';', names = ['R','Lengh', 'SNR', 'error', 'method'])

# %%
df_polar[0:5]
# Out:
#      R  Lengh  SNR     error                             method
# 0  128    0.5  1.0  0.851789  BEC_1_user_with_one_in_the_middle
# 1  128    0.5  1.5  0.728863  BEC_1_user_with_one_in_the_middle
# 2  128    0.5  2.0  0.556174  BEC_1_user_with_one_in_the_middle
# 3  128    0.5  2.5  0.393391  BEC_1_user_with_one_in_the_middle
# 4  128    0.5  3.0  0.273373  BEC_1_user_with_one_in_the_middle

# %%
df_polar[5:10]
# Out:
#      R  Lengh  SNR     error                             method
# 5  128    0.4  1.0  0.016949  BEC_1_user_with_one_in_the_middle
# 6  128    0.4  1.5  0.005147  BEC_1_user_with_one_in_the_middle
# 7  128    0.4  2.0  0.001200  BEC_1_user_with_one_in_the_middle
# 8  128    0.4  2.5  0.000290  BEC_1_user_with_one_in_the_middle
# 9  128    0.4  3.0  0.000040  BEC_1_user_with_one_in_the_middle

# %%
df_polar[10:15]
# Out:
#      R  Lengh  SNR     error                             method
# 10  64    0.5  1.0  0.569476  BEC_1_user_with_one_in_the_middle
# 11  64    0.5  1.5  0.421941  BEC_1_user_with_one_in_the_middle
# 12  64    0.5  2.0  0.338066  BEC_1_user_with_one_in_the_middle
# 13  64    0.5  2.5  0.224921  BEC_1_user_with_one_in_the_middle
# 14  64    0.5  3.0  0.150240  BEC_1_user_with_one_in_the_middle

# %%
df_polar[27:34]
# Out:
#       R  Lengh  SNR     error                             method
# 27  128    0.2 -4.0  0.168350  BEC_1_user_with_one_in_the_middle
# 28  128    0.2 -3.5  0.073964  BEC_1_user_with_one_in_the_middle
# 29  128    0.2 -3.0  0.024876  BEC_1_user_with_one_in_the_middle
# 30  128    0.2 -2.5  0.009053  BEC_1_user_with_one_in_the_middle
# 31  128    0.2 -2.0  0.002393  BEC_1_user_with_one_in_the_middle
# 32  128    0.2 -1.5  0.000420  BEC_1_user_with_one_in_the_middle
# 33  128    0.2 -1.0  0.000110  BEC_1_user_with_one_in_the_middle

# %%
df_ldpc[0:7]
#df_ldpc[7:14]
#df_ldpc[24:31]
#df_ldpc[31:38]
# Out:
#      R  Lengh  SNR   error method
# 0  128    0.2 -4.0  0.0320   LDPC
# 1  128    0.2 -3.5  0.0166   LDPC
# 2  128    0.2 -3.0  0.0054   LDPC
# 3  128    0.2 -2.5  0.0019   LDPC
# 4  128    0.2 -2.0  0.0008   LDPC
# 5  128    0.2 -1.5  0.0005   LDPC
# 6  128    0.2 -1.0  0.0001   LDPC

# %%
df_ldpc[14:19]
# Out:
#       R  Lengh  SNR   error method
# 14  128    0.4  1.0  0.0140   LDPC
# 15  128    0.4  1.5  0.0081   LDPC
# 16  128    0.4  2.0  0.0056   LDPC
# 17  128    0.4  2.5  0.0035   LDPC
# 18  128    0.4  3.0  0.0016   LDPC

# %%
df_ldpc[:25]
# Out:
#       R  Lengh  SNR   error method
# 0   128    0.2 -4.0  0.0320   LDPC
# 1   128    0.2 -3.5  0.0166   LDPC
# 2   128    0.2 -3.0  0.0054   LDPC
# 3   128    0.2 -2.5  0.0019   LDPC
# 4   128    0.2 -2.0  0.0008   LDPC
# 5   128    0.2 -1.5  0.0005   LDPC
# 6   128    0.2 -1.0  0.0001   LDPC
# 7   128    0.3 -2.0  0.0269   LDPC
# 8   128    0.3 -1.5  0.0269   LDPC
# 9   128    0.3 -1.0  0.0120   LDPC
# 10  128    0.3 -0.5  0.0048   LDPC
# 11  128    0.3  0.0  0.0019   LDPC
# 12  128    0.3  0.5  0.0016   LDPC
# 13  128    0.3  1.0  0.0006   LDPC
# 14  128    0.4  1.0  0.0140   LDPC
# 15  128    0.4  1.5  0.0081   LDPC
# 16  128    0.4  2.0  0.0056   LDPC
# 17  128    0.4  2.5  0.0035   LDPC
# 18  128    0.4  3.0  0.0016   LDPC
# 19  128    0.5  1.0  0.1013   LDPC
# 20  128    0.5  1.5  0.0528   LDPC
# 21  128    0.5  2.0  0.0383   LDPC
# 22  128    0.5  2.5  0.0339   LDPC
# 23  128    0.5  3.0  0.0107   LDPC
# 24   64    0.2 -4.0  0.0806   LDPC

# %%
df_ldpc[38:43]
# Out:
#      R  Lengh  SNR   error method
# 38  64    0.4  1.0  0.0538   LDPC
# 39  64    0.4  1.5  0.0336   LDPC
# 40  64    0.4  2.0  0.0273   LDPC
# 41  64    0.4  2.5  0.0197   LDPC
# 42  64    0.4  3.0  0.0126   LDPC

# %%
df_ldpc[43:]
# Out:
#      R  Lengh  SNR   error method
# 43  64    0.5  1.0  0.2586   LDPC
# 44  64    0.5  1.5  0.1705   LDPC
# 45  64    0.5  2.0  0.0469   LDPC
# 46  64    0.5  2.5  0.0647   LDPC
# 47  64    0.5  3.0  0.0257   LDPC

# %%
#L = 128 R = 0.2
df1 = np.log10(df_ldpc[0:7]['error'])
df2 = np.log10(df_polar[27:34]['error'])

#L = 128 R = 0.4
#df1 = np.log10(df_ldpc[14:19]['error'])
#df2 = np.log10(df_polar[5:10]['error'])




#L = 64 R = 0.2
#df1 = np.log10(df_ldpc[24:31]['error'])
#df2 = np.log10(df_polar[20:27]['error'])


#L = 64 R = 0.4
#df1 = np.log10(df_ldpc[38:43]['error'])
#df2 = np.log10(df_polar[15:20]['error'])

x = np.arange(-4.0,-0.5,0.5)
xnew = np.linspace(x.min(),x.max(),7)
smooth_df1 = spline(x,df1,xnew)
smooth_df2 = spline(x,df2,xnew)

# %%
x.shape
# Out:
# (7,)

# %%
plt.figure(figsize=(7.5,5))
plt.plot(xnew,smooth_df1, "bo-", label="LDPC")
plt.plot(xnew,smooth_df2, "ro-", label="Polar Codes") 
plt.xlabel("SNR, dB")
plt.ylabel("log10(FER)")
plt.grid()
plt.title('Length = 128 Rate = 0.2')
plt.legend(loc='upper right')
plt.show()
